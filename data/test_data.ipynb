# %%
import pandas as pd
import struct
import gzip
import json

# %%
with open("data/Amazon Product Reviews/Video_Games.json") as f:
    Video_Games = [json.loads(line) for line in f]
df = pd.DataFrame(Video_Games)

# %%
df = df.drop('style', axis=1)
df = df.drop('image', axis=1)

# %%
df.to_csv('data/Amazon Product Reviews/video_games.csv', index=False)

# %%
df = pd.read_csv('data/Amazon Product Reviews/video_games.csv')
# Out:
# /var/folders/k8/mpr1wsg938l9tll0w30rp4mw0000gn/T/ipykernel_57317/2431057379.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Amazon Product Reviews/video_games.csv')

# %%
df.head(20)
# Out:
#     overall  verified   reviewTime      reviewerID        asin  \
# 0       1.0      True   06 9, 2014  A21ROB4YDOZA5P  0439381673
# 1       3.0      True  05 10, 2014  A3TNZ2Q5E7HTHD  0439381673
# 2       4.0      True   02 7, 2014  A1OKRM3QFEATQO  0439381673
# 3       1.0      True   02 7, 2014  A2XO1JFCNEYV3T  0439381673
# 4       4.0      True  01 16, 2014  A19WLPIRHD15TH  0439381673
# 5       5.0      True   01 7, 2014  A1TLA7XXSZMTS7  0439381673
# 6       3.0      True  10 22, 2013  A3I9GK5OO42B0I  0439381673
# 7       5.0     False  10 21, 2013  A3TPP95Y9DH3L9  0439381673
# 8       5.0      True  10 29, 2012  A19GOZTT15KPG1  0439381673
# 9       5.0     False   02 8, 2010  A1441WFJ5KRP7J  0439381673
# 10      5.0      True  05 28, 2017   ATVYWID968EUQ  0439381673
# 11      5.0      True  03 30, 2017  A3FGRYQWUEM6UP  0439381673
# 12      1.0      True  03 17, 2017   AKQPJ6MMWXRP9  0439381673
# 13      1.0      True   03 1, 2017   AK893YQY5FJIP  0439381673
# ...

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("example").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/06 10:52:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
demo = spark.read.csv('data/Amazon Product Reviews/video_games.csv', header=True, inferSchema=True)
